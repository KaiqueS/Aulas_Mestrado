# %% [markdown]
# # Gary King - Replication, Replication
#
# <b>Problems In Empirical Political Science</b>
#
# King argues that it is only possible to fully understand an emp. analysis when the process used on the latter is completely accessible to any other researcher. By process, the author means both data generation and data analysis. To be precise, it is not required that a replication to be indeed performed, but only for replications to be feasible.
#
# The author says that it is not rare for works which do not follow the replication standard to face problems. Following the standard, even if no intention to provide replicability, may lead the reasearch to discover problems in its own analysis or data collection process. Aside from that, not following the standard itself harms research progress. If results cannot be guaranteed to be true, what is the purpose of trying to read a work with those results?
#
# Replication by itself might lead to better research comprehension and evaluation, because how one gets and measure data by itself provides information about the results, and, consequently, about the world to which the latter are related. Proceeding as proposed is the best way to further advance with science, since, by allowing for replication, it is possible to build new methodologies upon current data or even to add more data to an existent dataset. Replication cuts the cost of advancing with research by making the latter easier, whereas no replicability makes it more expensive for an study to be used, since no one will waste its time with something that might not be right after all.
#
# <b>Proposed Solutions</b>
#
# King proposes solutions applicable by the many parts that are involved, directly or not, in the scientific endeavor.
#
# 1. <b>Authors</b>
#
# Authors should follow the replication standard and provide as much information as possible about how they proceeded to gather and analyze data. To do so, the authors must:
#
# * Create a Replication Data Set, which must include all data necessary to replicate the results of the research, and provide public access to it. King proceeds babbling about how and where to store data digitally and whatsoever
#
#
# 2. <b>Tenure And Promotion Review Committees</b>
#
# Its purpose is to promote chosen candidates. The choice must be made based on wether and how much a candidate adheres to the replication standard
#
# 3. <b>Graduate Programs</b>
#
# Graduation programs should induce its students to adhere to the replication standard, either in its courses( e.g., by making students replicate published works' results ), or by proposing rules, to be followed by any student when writing their dissertation, that are in accord with the replication standard.
#
# 4. <b>Editors And Reviewers Of Books And Journals</b>
#
# Those must try to enforce replicability by requiring submitted work to adhere to the replication standard. This can be done, e.g., by requiring specification of where the author will provide its data and when. Also, journals could also require more reviewers to try and replicate submitted but unpublished papers, so as to make it possible to give some feedback to authors, where the latter might, then, make further ajudstments to their papers.
#
# <b>Important Exceptions</b>
#
# Exceptions to full submition of data.
#
#  1. Confidentiality: There are some cases, beyond the mere avoidance of publishing names and addresses or any personal information of respondents, where data must not be provided. Whenever any extra sensible information is present, or when data is proprietary, confidentiality must be respected, and the corresponding data must not be publicly provided.
#
#
#  2. Right Of First Publication: Sometimes the data for a research might not be imediately provided, so as to grant the right of first publication, i.e., that the person that collected the data must be the first to use it in a publication. When this happens, the research might ask for an embargo for a period of time before the data is made public. Those cases must be rare, and, it might be made necessary to submit data exclusively used on the research, so as to make it possible for the results to be verified and replicated. Sometimes, this embargo might also be used so as to make it possible for the researcher to better work and format a subset of the data intended to be used in its study. In the latter cases, a copy of the old not-formatted data must also be submitted.
#
# <b>Support For These Policies</b>
#
# Those recommendations are growing in adoption, be it by journals, graduate programs, and whatsoever.
#
# <b>Replication Policy Discussions</b>
#
# <b>Questions And Answers</b>
#
# * Will a replication standard reduce incentives for individual investigators to collect large and dificult data sets?
#
# King answer is no, it will not reduce incentives. Being explicit about how data was gathered and analyzed will only make the work more valuable, and, thus, extend its reach( in terms of citations ). Replicable work, as argued above, is more trustable, and, thus more prone to be read and used by others, sice its results are more granted to be right. Also, not all data is required to be submitted, only those used in a study. So, all unused data might be handled by the research in another paper.
#
#
# * Implementing the replication standard will make much more data available through public archives. Won't an unintended consequence of this proposal be that future scholars will spend most of their time analyzing existing data rather than collecting new data, spending time in the computer lab rather than in the field?
#
# King disagrees. He argues that the exact opposite of this happens. Increasing availability increases propensity to collect new data. Also, data collection gets easier as collection is done, because procedures used to gather data are more known and enhanced.
#
# * Wouldn't it be better i f all journals and book series adopted exactly he same policy at the same time?
#
# Differences between journals purposes justifies differences in replication policies
#
# * If our journal requires adherence to the replication standard, won't authors send work elsewhere or not publish articles and save their work until a book manuscript is ready?
#
# Might have been true, but it is not necessary to happen. Many publishers are adopting replication policies, and it also might happen that the author agrees with required policies.
#
# * If I give you my data, isn't there a chance that you will find out that I'm wrong and tell everyone?
#
# Yes. But this is a requirement for the advance of science. Finding errors and correcting them
#
# * Shouldn't editors collect replication data sets to guarantee that they have been submitted?
#
# Filtering data sets might prevent this.
#
# * If submitting replication data sets is in the interest of individual investigators, why do we need journals and book presses to require their submission?
#
# So as to make it more costly not to adhere to replication standards.
#
# * Why are we worrying ourselves with what might be called "duplication" of misting research? Isn't the more important question actual replication where the same measurements are applied to new substantive areas, countries, or time periods?

# %% [markdown]
# # A Importância da Replicabilidade na Ciência Política: O Caso do SIGOBR12
#
# ### Enivaldo Carvalho da Rocha
# ### Ranulfo Paranhos
# ### Dalson Britto Figueiredo Filho
# ### Erinaldo Ferreira do Carmo
#
# <b>2 - Replicar É Preciso</b>
#
# Há três dimensões na replicabilidade, quais sejam:
#
# * Substantiva: aprimoramento da qualidade nas pesquisas e proporção do acúmulo de conhecimento
#
# * Pedagógica: viabilizar o estudo, por parte de pós-graduandos, de análise de dados e suas técnicas
#
# * Transparência: expor erros honestos ou desonestos, de forma que seja possível se proteger dos mesmos
#
# <b>2.1 O Que É Replicabilidade</b>
#
# Para os autores, de acordo com King, replicabilidade é o fornecimento, por parte do pesquisador, de informações suficientes para se entender, avaliar e replicar resultados de um estudo. Essas informações são justamente um passo-a-passo sobre como foram coletados e analisados os dados utilizados na pesquisa.
#
# <b>NdR 12:</b> replicação, reanálise, verificação e análise secundária são conceitos diferentes.
#
# * Replicação: coleta independente de dados
#
# * Reanálise: mesmo estudo, não necessariamente mesma base de dados
#
# * Verificação: mesmo estudo, mesma base de dados
#
# * Análise secundária: mesmo banco de dados, problema diferente
#
# <b>2.2 Dimensão Substantiva</b>
#
# Existem algumas vantagens de se disponibilizar um estudo replicável. A primeira, segundo GMS( 2003 ), é que autores que fazem trabalhos replicáveis são mais citados. A segunda é a própria replicabilidade e uma consequência didática desta, qual seja, a possibilidade de se desenvolver melhores análises e da exposição de possíveis erros em estudos já feitos. A maior possibilidade de expor erros garante uma maior falseabiliade dos estudos feitos, o que seria outra vantagem da replicabilidade.
#
# Os autores também afirmam que Meier( 1995 ) identifica outros dois pontos, quais sejam, um aumento na validade e credibilidade do trabalho feito.
#
# <b>2.3 Dimensão Pedagógica</b>
#
# Replicabilidade tem um grande efeito didático, isto se dá pois, quando a pesquisa é replicável, estudantes podem refazer os passos que levaram o autor ao resultado obtido na própria pesquisa.
#
# <b>2.4 Dimensão Transparência</b>
#
# Segundo os autores, Charles Babbage identifica três modos de fraude:
#
# 1. Aparamento: ajuste, ou manipulação, de dados
#
# 2. Peneiramento: seleção apenas dos resultados que confirmam a hipótese
#
# 3. Falsificação: invenção de dados, com a intenção de descrever um padrão
#
# <b>O Caso Do SIGOBr</b>
#
# Tem como objetivo integrar práticas desejáveis de replicabilidade em um único produto. Para isso, compõe-se por cinco atividades principais:
#
# * Compilação de base de dados: junção de dados de diferentes bancos de dados e diferentes temas, em níveis estaduais e municipais
#
# * Replicabilidade: incentivar replicação de estudos publicados. Tem como objetivo aprimorar pesquisas, educar alunos e verificar resultados já estabelecidos.
#
# * Repositório de dados: servir como repositório de dados
#
# * Cursos de capacitação: fornecer treinamento técnico
#
# * Divulgação: exposição de resultados com o intuito de tornar os mesmos públicos.
#
#
# 1. Identificação Do Projeto
#
# 2. Resumo
#
# 3. Etapas/Atividades
#
# Dados recolhidos a níveis municipal e estadual. Porém, com o intuito de aumentar a acessibilidade, disponibilizar-se-á também dados de níveis regional e nacional.
#
# 4. Definição De Problema
#
# Possui duas justificativas:
#
# * Acadêmica: disponibilizar dados contribui com aprimoramento do conhecimento científico
#
# * Prática: tal conhecimento pode contribuir com a elaboração de pesquisas mais aplicadas ou políticas mais efetivas
#
# 5. Objetivos
#
# 6. Metodologia
#
# Metodologia de pesquisa comparada, a qual, segundo os autores, Ragin afirma possibilitar afirmações sobre padrões empiricamente observados
#
# Tal metodologia possui duas vantagens:
#
# * Viajabilidade dos conceitos
#
# * Generalizabilidade dos resultados para outros contextos que não os que os mesmos foram encontrados
#
#
# 7. Resultados esperados
#
# 8. Relevância Científica
#
# Com a criação e fornecimento público de um bancos de dados, os quais dizem respeito à diversos temas, os autores pretendem suprir e facilitar o acesso à informações confiáveis e academicamente relevantes, tanto do ponto de vista da produção científica, quanto do ponto de vista pedagógico.

# %% [markdown]
# # Paul M. Kellstedt, Guy D. Whitten - The Fundamentals Of Political Science Research
#
# <b>Chapter 1 - The Scientific Study Of Politics</b>
#
# What it means to study Political Science scientifically and how to move from causal theories to scientific knowledge.
#
# <b>1.1 - Political Science?</b>
#
# It is all about the scientific study of political phenomena.
#
# The authors have three goals in mind with this book:
#
# 1. Facilitate consumption of academic research
#
# 2. To make we better consumers of information in general
#
# 3. Make we better researchers, and produce higher quality material
#
# <b>1.2 Approachinh Politics Scientifically: The Search For Causal Explanations</b>
#
# According to the authors, what makes political scientists scientists is that they develop and test <b>theories</b>, where these are <i>propositions about what causes some phenomenon</i>.
#
# From the development of a scientific theory, there is a pathway to the scientific inquiry, which is summarized as follows: afther the development of a theory, we create, from those, testable hypotheses.
#
# <b>Hypotheses</b> are statement based on the theory about how a phenomenon works, where this working must be observable. For any hypothesis, there exists one corresponding <b>null hypothesis</b>, which is defined as what we would observe if the relation proposed from the original hypothesis were not true. To determine whether or not hypotheses are true, we proceed to <b>hypotheses testing</b>, which happens as we collect and evaluate evidences about those hypotheses. Hypothesis survival grants, thus and according to the authors, more credbility to it and its supporting theory.
#
# In what follows, there is an image, created by Kellstedt and Whitten( 2018 ) representing the pathway to scientific knowledge.
#
# ![image.png](attachment:image.png)
#
# Another part of the scientific inquiry, according to the authors, is skeptcism. It is necessary to doubt not only other, concorrent, theories, but our own too, so as to make us test them more and more accurately. This is the only way for us to be able to trust in the theories, even though, as the authors say, it is not indeed possible to <i>prove</i> a scientific theory. But, after being thoroughly tested, theories can be used as basis where knowledge will be built up on.
#
# A set of shared assumptions and theories is called <b>paradigm</b>, and the formation of the latter occurs as theories and assumptions survives testing. Works around a paradigm, as, e.g., more technical and specific questions, are called <b>normal science</b>. Of course, it might happen that, as science advances, new and more strong problems are posed to the current paradigm, probabily undermining it. When this happens, the field suffers a <b>paradigm shift</b>, where new assumptions and theories replace old ones.
#
# <b>1.3 Thinking About The World In Terms Of Variables And Causal Explanations</b>
#
# The authors say that political scientists uses <b>variables</b> and <b>causal relationships</b> between those to study the world. Variables have both <b>labels</b> and <b>values</b>. The former describes what the variables are, where the latter represents possible instances of the variable.
#
# The authors ask the readers to recall that a theory is a proposition of how an independent variable is related to a dependent variable, i.e., how changes on the latter affects the former. This is the same as saying that the independent variable causes the dependent variable. But, to be able to caught precisely how much one variable causes the other, it is necessary to <b>operationalize</b>, i.e., <b>measure</b>, this causal effect or relation. The authors say that there are many ways to operationalize variables, there will also be many hypotheses to be tested, and, consequently, many possibilities to test our theories against data.
#
# There are different forms in which the relation between variables may come. For example, there might happen that two variables have a <b>positive relationship</b>, where higher values of both varibles tend to coincide. On the other way around, variables may have <b>negative relationship</b>, where higher values of the independent variable are associated with lower variables of the dependent variable. Those relationships are also called <b>direction</b> of our hypotheses. We, thereafter, verify our hypothesis against data after knowing what kind of relationship to expect from the former.
#
# <b>1.4 Models Of Politics</b>
#
# The construction of those relationships between variables, more specifically, to propose theoris about how independent variables causally influence dependent variables that we want to explain is the same as to construct of what the authors call <b>theoretical models</b>. Those models, as the authors quote James Rogers( 2006 ), even though cause proposital distortions to the reality we want to explain, provide us with the possibility to understand how the features that we put in the model behave among themselves.
#
# <b>1.5 Rules Of The Road To Scientific Knowledge About Politics</b>
#
# <b>1.5.1 - Focus On Causality</b>
#
# Causes, not only <b>covariation</b>. Do not suppose the former from the latter.
#
# <b>1.5.2 - Don't Let Data Alone Drive Your Theories</b>
#
# Theorizing before data, not after.
#
# <b>1.5.3 - Consider Only Empirical Evidence</b>
#
# The authors say that empirical observations are the only admissable form of evidence for arguments' validity. Avoid any kind of normative propositions.
#
# <b>1.5.4 -  Check Your Ideology at the Door and Avoid Normative Statements</b>
#
# <b>1.5.5 - Pursue Both Generality And Parsimony</b>
#
# Aim for Generality and Simplicity
#
# <b>1.6 A Quick Look Ahead</b>
#
# <b>Chapter 2 - The Art Of Theory Building</b>
#
# <b>2.1 Good Theories Come From Good Theory-Building Strategies</b>
#
# Even though there is no surefire way to come up with good theories, there are strategies that, when followed, might make theories more prone to be good than bad.
#
# <b>2.2 Promising Theories Offer Answers To Interesting Research Questions</b>
#
# Since from theories onde derives hyphoteses, and given that hyphoteses must be empirically tested, we might want to come up with theories that, when tested and confirmed, would provide the scientific community with relevant knowledge. If this is not the case, i.e., if our theory does not provide the scientific community with relevant knowledge, then we should reconsider it.
#
# <b>2.3 Identifying Interesting Variation</b>
#
# Find variations, search for generizable patterns. When considering phenomena as study objects, search for those that present some variation. Try to come up with or find patterns to explain that variation. Since from theories we get to hypotheses about how variables affect each other, searching for variation in the variable that we want to explain provides us with a starting point.
#
# The authors consider, initially, two dimensions where to observe variation in our dependent variables, be them:
#
# * The time dimension: periods or intervals of time where we want to observe our phenomenon of interest
#
# * The spatial dimension: the units of observation, e.g., people, states, natios, etc.
#
# The authors, in their book, will focus on measuring the dependent variables when one of those two dimensions remains constant. This divides possible measures into two types:
#
# 1. Cross-sectional Measure: time dimension remains constant, spatial varies so as to include more than one spatial unit.
#
# 2. Time-series Measure: spatial units remains constant while the dependent variable is measured across multiple points of time.
#
# <b>2.3.1 Cross-Sectional Example</b>
#
# Be careful to choose measures comparable across units, e.g., conversions for different money currencies.
#
# <b>2.3.2 Time-Series Example</b>
#
# <b>2.4 Learning To Use Your Knowledge</b>
#
# Aim for generalizable theories and for generalization.
#
# <b>2.4.1 Moving From A Specific Event To More General Theories</b>
#
# <b>2.4.2 Know Local, Think Global: Can You Drop The Proper Nouns?</b>
#
# From local reasoning, try to reach global, generalizable, theories
#
# <b>2.5 Three Strategies Toward Developing An Original Theory</b>
#
# The autor suggests using mathematical notation as an assisting tool to help on the development of new theories. This process allows for three strategies to be usable:
#
# 1. A new Y( and an existing X )
#
# 2. An existing Y and a new X
#
# 3. A new Z which modifies X &rarr; Y
#
# <b>2.5.1 Theory Type 1: A New Y( and Some X )</b>
#
# Create or discover a new dependent variable, then, proceed to theorize about what( a independent variable that ) might cause its variation. But, be sure that this new dependent variable is indeed new.
#
# <b>2.5.1 Theory Type 2: An Existing Y And A New X</b>
